# %%
## Stable Release, Version 1.0 Grid HFT System, DEVELOPED BY FEJIRO E. JUN 2024 ##

import MetaTrader5 as mt5
import time

# Symbol to trade
symbol = "USDJPYm"

# Connect to MetaTrader 5
if not mt5.initialize():
    print("Failed to initialize, error code =", mt5.last_error())
    quit()

# Get the current price
def get_current_price(symbol):
    ticker = mt5.symbol_info_tick(symbol)
    if ticker is None:
        raise Exception(f"Failed to get ticker for {symbol}")
    return ticker.bid, ticker.ask

# Place an order
def place_order(symbol, order_type, volume, price, sl, tp):
    request = {
        "action": mt5.TRADE_ACTION_PENDING,
        "symbol": symbol,
        "volume": volume,
        "type": order_type,
        "price": price,
        "sl": sl,
        "tp": tp,
        "deviation": 10,
        "magic": 234000,
        "comment": "Grid strategy",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_RETURN,
    }
    
    result = mt5.order_send(request)
    if result.retcode != mt5.TRADE_RETCODE_DONE:
        print("Failed to send order:", result)
        return None
    return result

# Grid strategy
def grid_strategy(symbol):
    volume = 0.1  # Define your volume
    pips = 0.1  # 10 pips for JPY pairs, adjust as necessary
    sl_tp_multiplier = 4  # Multiplier for SL and TP levels

    bid, ask = get_current_price(symbol)
    current_price = (bid + ask) / 2

    # Define sell stops
    last_sell_tp = None
    for i in range(1, 4):
        price = current_price - i * pips
        sl = price + sl_tp_multiplier * pips
        tp = price - sl_tp_multiplier * pips
        last_sell_tp = tp  # Save the TP level of the last sell stop
        place_order(symbol, mt5.ORDER_TYPE_SELL_STOP, volume, price, sl, tp)

    # Place buy limit at the position of the last sell stop's TP level
    buy_limit_price = last_sell_tp
    buy_limit_sl = buy_limit_price - sl_tp_multiplier * pips
    buy_limit_tp = buy_limit_price + sl_tp_multiplier * pips
    place_order(symbol, mt5.ORDER_TYPE_BUY_LIMIT, volume, buy_limit_price, buy_limit_sl, buy_limit_tp)

    # Define buy stops
    last_buy_tp = None
    for i in range(1, 4):
        price = current_price + i * pips
        sl = price - sl_tp_multiplier * pips
        tp = price + sl_tp_multiplier * pips
        last_buy_tp = tp  # Save the TP level of the last buy stop
        place_order(symbol, mt5.ORDER_TYPE_BUY_STOP, volume, price, sl, tp)

    # Place sell limit at the position of the last buy stop's TP level
    sell_limit_price = last_buy_tp
    sell_limit_sl = sell_limit_price + sl_tp_multiplier * pips
    sell_limit_tp = sell_limit_price - sl_tp_multiplier * pips
    place_order(symbol, mt5.ORDER_TYPE_SELL_LIMIT, volume, sell_limit_price, sell_limit_sl, sell_limit_tp)

# Run the grid strategy
grid_strategy(symbol)

# Disconnect from MetaTrader 5
mt5.shutdown()
# Out:
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.7065, stoplimit=0.0, sl=158.1065, tp=157.3065, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.6065, stoplimit=0.0, sl=158.00650000000002, tp=157.2065, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.5065, stoplimit=0.0, sl=157.9065, tp=157.10649999999998, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.10649999999998, stoplimit=0.0, sl=156.70649999999998, tp=157.5065, deviation=10, type=2, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.9065, stoplimit=0.0, sl=157.5065, tp=158.3065, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.0065, stoplimit=0.0, sl=157.60649999999998, tp=158.4065, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.1065, stoplimit=0.0, sl=157.7065, tp=158.50650000000002, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.50650000000002, stoplimit=0.0, sl=158.90650000000002, tp=158.1065, deviation=10, type=3, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# True

# %%
## Stable Release, Version 2.0 Grid HFT System, DEVELOPED BY FEJIRO E. JUN 2024 ##
## Update: added tighter stoploss and timechecker if all trades are closed after 5 mins, create new grid##

import MetaTrader5 as mt5
import time

# Symbol to trade
symbol = "USDJPYm"

# Connect to MetaTrader 5
if not mt5.initialize():
    print("Failed to initialize, error code =", mt5.last_error())
    quit()

# Get the current price
def get_current_price(symbol):
    ticker = mt5.symbol_info_tick(symbol)
    if ticker is None:
        raise Exception(f"Failed to get ticker for {symbol}")
    return ticker.bid, ticker.ask

# Place an order
def place_order(symbol, order_type, volume, price, sl, tp):
    request = {
        "action": mt5.TRADE_ACTION_PENDING,
        "symbol": symbol,
        "volume": volume,
        "type": order_type,
        "price": price,
        "sl": sl,
        "tp": tp,
        "deviation": 10,
        "magic": 234000,
        "comment": "Grid strategy",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_RETURN,
    }
    
    result = mt5.order_send(request)
    if result.retcode != mt5.TRADE_RETCODE_DONE:
        print("Failed to send order:", result)
        return None
    return result

# Grid strategy
def grid_strategy(symbol):
    volume = 0.1  # Define your volume
    pips = 0.1  # 10 pips for JPY pairs, adjust as necessary

    bid, ask = get_current_price(symbol)
    current_price = (bid + ask) / 2

    # Define sell stops
    last_sell_tp = None
    for i in range(1, 4):
        price = current_price - i * pips
        tp = price - 4 * pips  # Take profit 4 levels away
        sl = price + 2 * pips  # Stop loss half of take profit
        last_sell_tp = tp  # Save the TP level of the last sell stop
        place_order(symbol, mt5.ORDER_TYPE_SELL_STOP, volume, price, sl, tp)

    # Place buy limit at the position of the last sell stop's TP level
    buy_limit_price = last_sell_tp
    buy_limit_tp = buy_limit_price + 4 * pips
    buy_limit_sl = buy_limit_price - 2 * pips
    place_order(symbol, mt5.ORDER_TYPE_BUY_LIMIT, volume, buy_limit_price, buy_limit_sl, buy_limit_tp)

    # Define buy stops
    last_buy_tp = None
    for i in range(1, 4):
        price = current_price + i * pips
        tp = price + 4 * pips  # Take profit 4 levels away
        sl = price - 2 * pips  # Stop loss half of take profit
        last_buy_tp = tp  # Save the TP level of the last buy stop
        place_order(symbol, mt5.ORDER_TYPE_BUY_STOP, volume, price, sl, tp)

    # Place sell limit at the position of the last buy stop's TP level
    sell_limit_price = last_buy_tp
    sell_limit_tp = sell_limit_price - 4 * pips
    sell_limit_sl = sell_limit_price + 2 * pips
    place_order(symbol, mt5.ORDER_TYPE_SELL_LIMIT, volume, sell_limit_price, sell_limit_sl, sell_limit_tp)

# Check if all pending orders have been executed
def all_orders_executed():
    orders = mt5.orders_get(symbol=symbol)
    return orders is None or len(orders) == 0

# Main loop
while True:
    # Run the grid strategy
    grid_strategy(symbol)
    
    # Wait for 5 minutes and check if all orders have been executed
    time.sleep(300)
    
    # If all orders are executed, create a new grid
    if all_orders_executed():
        print("All orders executed. Creating a new grid.")
        grid_strategy(symbol)
    else:
        print("Orders still pending. Checking again in 5 minutes.")

# Disconnect from MetaTrader 5
mt5.shutdown()
# Out:
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.7055, stoplimit=0.0, sl=157.9055, tp=157.3055, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.6055, stoplimit=0.0, sl=157.8055, tp=157.2055, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.50549999999998, stoplimit=0.0, sl=157.70549999999997, tp=157.10549999999998, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.10549999999998, stoplimit=0.0, sl=156.9055, tp=157.50549999999998, deviation=10, type=2, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=157.9055, stoplimit=0.0, sl=157.7055, tp=158.3055, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.00549999999998, stoplimit=0.0, sl=157.8055, tp=158.4055, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.1055, stoplimit=0.0, sl=157.90550000000002, tp=158.5055, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.1, price=158.5055, stoplimit=0.0, sl=158.7055, tp=158.1055, deviation=10, type=3, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))

# %%
import MetaTrader5 as mt5
import time
import pandas as pd
import os

# Symbol to trade
symbol = "USDJPYm"

# Initialize the DataFrame for logging
columns = ['timestamp', 'order_type', 'volume', 'price', 'sl', 'tp', 'result']
trade_log_df = pd.DataFrame(columns=columns)

# Connect to MetaTrader 5
if not mt5.initialize():
    print("Failed to initialize, error code =", mt5.last_error())
    quit()

# Get the current price
def get_current_price(symbol):
    ticker = mt5.symbol_info_tick(symbol)
    if ticker is None:
        raise Exception(f"Failed to get ticker for {symbol}")
    return ticker.bid, ticker.ask

# Function to log buy/sell order details
def log_trade(order_type, volume, price, sl, tp, result):
    global trade_log_df
    print(f"Logging trade: {order_type}, {volume}, {price}, {sl}, {tp}, {result.retcode if result else 'failed'}")
    
    new_trade = pd.DataFrame([{
        'timestamp': pd.Timestamp.now(),
        'order_type': order_type,
        'volume': volume,
        'price': price,
        'sl': sl,
        'tp': tp,
        'result': result.retcode if result else 'failed'
    }])
    
    print(f"New trade DataFrame:\n{new_trade}")
    
    if not new_trade.isna().all().all():
        trade_log_df = pd.concat([trade_log_df, new_trade], ignore_index=True)
        print(f"Updated trade_log_df:\n{trade_log_df}")

# Function to save DataFrame into CSV file locally
def save_log_to_csv():
    desktop = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop')
    filepath = os.path.join(desktop, 'gridbotlog.csv')
    trade_log_df.to_csv(filepath, index=False)

# Place an order with correct price precision
def place_order(symbol, order_type, volume, price, sl, tp):
    # Ensure the price has the correct precision
    price = round(price, 3)  # For JPY pairs, using 3 decimal places
    sl = round(sl, 3)
    tp = round(tp, 3)

    request = {
        "action": mt5.TRADE_ACTION_PENDING,
        "symbol": symbol,
        "volume": volume,
        "type": order_type,
        "price": price,
        "sl": sl,
        "tp": tp,
        "deviation": 10,
        "magic": 234000,
        "comment": "Grid strategy",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_RETURN,
    }
    
    result = mt5.order_send(request)
    
    if result.retcode != mt5.TRADE_RETCODE_DONE:
        print(f"Failed to send order: {result}")
        log_trade(order_type, volume, price, sl, tp, result)
        return None
    else:
        print(f"Order sent successfully: {result}")
        log_trade(order_type, volume, price, sl, tp, result)
    
    return result

# Update trailing stop loss for open positions
def update_trailing_stop(symbol, trailing_stop_distance):
    positions = mt5.positions_get(symbol=symbol)
    if positions is None:
        print(f"No positions found for {symbol}, error code:", mt5.last_error())
        return
    
    for position in positions:
        if position.type == mt5.ORDER_TYPE_BUY:
            new_sl = mt5.symbol_info_tick(symbol).bid - trailing_stop_distance
            if new_sl > position.sl:
                modify_order(position.ticket, new_sl, position.tp)
        elif position.type == mt5.ORDER_TYPE_SELL:
            new_sl = mt5.symbol_info_tick(symbol).ask + trailing_stop_distance
            if new_sl < position.sl:
                modify_order(position.ticket, new_sl, position.tp)

# Modify an existing order's stop loss and take profit
def modify_order(position_ticket, new_sl, new_tp):
    request = {
        "action": mt5.TRADE_ACTION_SLTP,
        "position": position_ticket,
        "sl": new_sl,
        "tp": new_tp,
        "deviation": 10,
    }
    result = mt5.order_send(request)
    if result.retcode != mt5.TRADE_RETCODE_DONE:
        print(f"Failed to modify order: {result}")
        return None
    return result

# Grid strategy
def grid_strategy(symbol):
    volume = 0.05  # Define your volume/lotsize, adjust as necessary
    pips = 0.05  # pip distance, adjust as necessary

    bid, ask = get_current_price(symbol)
    current_price = (bid + ask) / 2

    # Define sell stops
    last_sell_tp = None
    for i in range(1, 4):
        price = current_price - i * pips
        tp = price - 4 * pips  # Take profit 4 levels away
        sl = price + 2 * pips  # Stop loss half of take profit
        last_sell_tp = tp  # Save the TP level of the last sell stop
        result = place_order(symbol, mt5.ORDER_TYPE_SELL_STOP, volume, price, sl, tp)
        if result is None:
            print(f"Invalid price for sell stop at {price}. Retrying with adjusted price.")
            # Adjust the price slightly and retry
            price = round(current_price - (i * pips * 1.01), 3)
            result = place_order(symbol, mt5.ORDER_TYPE_SELL_STOP, volume, price, sl, tp)
            if result is None:
                print(f"Failed to place adjusted sell stop order at {price}")
                continue

    # Place buy limit at the position of the last sell stop's TP level
    if last_sell_tp is not None:
        buy_limit_price = last_sell_tp
        buy_limit_tp = buy_limit_price + 4 * pips
        buy_limit_sl = buy_limit_price - 2 * pips
        result = place_order(symbol, mt5.ORDER_TYPE_BUY_LIMIT, volume, buy_limit_price, buy_limit_sl, buy_limit_tp)
        if result is None:
            print(f"Invalid price for buy limit at {buy_limit_price}. Retrying with adjusted price.")
            # Adjust the price slightly and retry
            buy_limit_price = round(last_sell_tp * 1.01, 3)
            result = place_order(symbol, mt5.ORDER_TYPE_BUY_LIMIT, volume, buy_limit_price, buy_limit_sl, buy_limit_tp)
            if result is None:
                print(f"Failed to place adjusted buy limit order at {buy_limit_price}")

    # Define buy stops
    last_buy_tp = None
    for i in range(1, 4):
        price = current_price + i * pips
        tp = price + 4 * pips  # Take profit 4 levels away
        sl = price - 2 * pips  # Stop loss half of take profit
        last_buy_tp = tp  # Save the TP level of the last buy stop
        result = place_order(symbol, mt5.ORDER_TYPE_BUY_STOP, volume, price, sl, tp)
        if result is None:
            print(f"Invalid price for buy stop at {price}. Retrying with adjusted price.")
            # Adjust the price slightly and retry
            price = round(current_price + (i * pips * 1.01), 3)
            result = place_order(symbol, mt5.ORDER_TYPE_BUY_STOP, volume, price, sl, tp)
            if result is None:
                print(f"Failed to place adjusted buy stop order at {price}")
                continue

    # Place sell limit at the position of the last buy stop's TP level
    if last_buy_tp is not None:
        sell_limit_price = last_buy_tp
        sell_limit_tp = sell_limit_price - 4 * pips
        sell_limit_sl = sell_limit_price + 2 * pips
        result = place_order(symbol, mt5.ORDER_TYPE_SELL_LIMIT, volume, sell_limit_price, sell_limit_sl, sell_limit_tp)
        if result is None:
            print(f"Invalid price for sell limit at {sell_limit_price}. Retrying with adjusted price.")
            # Adjust the price slightly and retry
            sell_limit_price = round(last_buy_tp * 1.01, 3)
            result = place_order(symbol, mt5.ORDER_TYPE_SELL_LIMIT, volume, sell_limit_price, sell_limit_sl, sell_limit_tp)
            if result is None:
                print(f"Failed to place adjusted sell limit order at {sell_limit_price}")

# Check if all pending orders have been executed
def all_orders_executed():
    orders = mt5.orders_get(symbol=symbol)
    return orders is None or len(orders) == 0

# Main loop
while True:
    # Run the grid strategy
    grid_strategy(symbol)
    
    # Wait for 1 hour and check if all orders have been executed before placing new ones
    time.sleep(3600)
    
    # If there are still pending orders, wait until the next iteration
    if not all_orders_executed():
        continue

    # Update trailing stop loss for open positions
    trailing_stop_distance = 2 * 0.1  # Example trailing stop distance, adjust as needed
    update_trailing_stop(symbol, trailing_stop_distance)

    # Save to CSV file function call
    save_log_to_csv()

# Disconnect from MetaTrader 5
mt5.shutdown()
# Out:
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.393, stoplimit=0.0, sl=160.493, tp=160.194, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.393, 160.493, 160.194, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066           5    0.05  160.393  160.493  160.194
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
#
#   result
# 0  10027
# Invalid price for sell stop at 160.3935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.393, stoplimit=0.0, sl=160.493, tp=160.194, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.393, 160.493, 160.194, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.443170           5    0.05  160.393  160.493  160.194
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
#
#   result
# 0  10027
# 1  10027
# Failed to place adjusted sell stop order at 160.393
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.344, stoplimit=0.0, sl=160.444, tp=160.144, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.344, 160.444, 160.144, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.456325           5    0.05  160.344  160.444  160.144
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
#
#   result
# 0  10027
# 1  10027
# 2  10027
# Invalid price for sell stop at 160.3435. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.343, stoplimit=0.0, sl=160.444, tp=160.144, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.343, 160.444, 160.144, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.465292           5    0.05  160.343  160.444  160.144
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# Failed to place adjusted sell stop order at 160.343
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.293, stoplimit=0.0, sl=160.393, tp=160.094, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.293, 160.393, 160.094, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.476005           5    0.05  160.293  160.393  160.094
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# Invalid price for sell stop at 160.2935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.292, stoplimit=0.0, sl=160.393, tp=160.094, deviation=10, type=5, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 5, 0.05, 160.292, 160.393, 160.094, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.488013           5    0.05  160.292  160.393  160.094
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5 2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# 5  10027
# Failed to place adjusted sell stop order at 160.292
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.094, stoplimit=0.0, sl=159.994, tp=160.293, deviation=10, type=2, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 2, 0.05, 160.094, 159.994, 160.293, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.509325           2    0.05  160.094  159.994  160.293
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5 2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6 2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# 5  10027
# 6  10027
# Invalid price for buy limit at 160.0935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=161.694, stoplimit=0.0, sl=159.994, tp=160.293, deviation=10, type=2, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 2, 0.05, 161.694, 159.994, 160.293, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.515862           2    0.05  161.694  159.994  160.293
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5 2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6 2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7 2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# 5  10027
# 6  10027
# 7  10027
# Failed to place adjusted buy limit order at 161.694
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.494, stoplimit=0.0, sl=160.394, tp=160.694, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.494, 160.394, 160.694, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.533212           4    0.05  160.494  160.394  160.694
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5 2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6 2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7 2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8 2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# 5  10027
# 6  10027
# 7  10027
# 8  10027
# Invalid price for buy stop at 160.4935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.494, stoplimit=0.0, sl=160.394, tp=160.694, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.494, 160.394, 160.694, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.545460           4    0.05  160.494  160.394  160.694
#
#    result
# 0   10027
# Updated trade_log_df:
#                    timestamp order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1 2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2 2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3 2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4 2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5 2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6 2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7 2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8 2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9 2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
#
#   result
# 0  10027
# 1  10027
# 2  10027
# 3  10027
# 4  10027
# 5  10027
# 6  10027
# 7  10027
# 8  10027
# 9  10027
# Failed to place adjusted buy stop order at 160.494
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.543, stoplimit=0.0, sl=160.444, tp=160.743, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.543, 160.444, 160.743, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.556029           4    0.05  160.543  160.444  160.743
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# Invalid price for buy stop at 160.5435. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.544, stoplimit=0.0, sl=160.444, tp=160.743, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.544, 160.444, 160.743, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.565843           4    0.05  160.544  160.444  160.743
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
# 11 2024-06-28 11:11:37.565843          4    0.05  160.544  160.444  160.743
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# 11  10027
# Failed to place adjusted buy stop order at 160.544
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.594, stoplimit=0.0, sl=160.494, tp=160.793, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.594, 160.494, 160.793, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.575860           4    0.05  160.594  160.494  160.793
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
# 11 2024-06-28 11:11:37.565843          4    0.05  160.544  160.444  160.743
# 12 2024-06-28 11:11:37.575860          4    0.05  160.594  160.494  160.793
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# 11  10027
# 12  10027
# Invalid price for buy stop at 160.5935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.595, stoplimit=0.0, sl=160.494, tp=160.793, deviation=10, type=4, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 4, 0.05, 160.595, 160.494, 160.793, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.583677           4    0.05  160.595  160.494  160.793
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
# 11 2024-06-28 11:11:37.565843          4    0.05  160.544  160.444  160.743
# 12 2024-06-28 11:11:37.575860          4    0.05  160.594  160.494  160.793
# 13 2024-06-28 11:11:37.583677          4    0.05  160.595  160.494  160.793
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# 11  10027
# 12  10027
# 13  10027
# Failed to place adjusted buy stop order at 160.595
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=160.793, stoplimit=0.0, sl=160.893, tp=160.594, deviation=10, type=3, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 3, 0.05, 160.793, 160.893, 160.594, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.587722           3    0.05  160.793  160.893  160.594
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
# 11 2024-06-28 11:11:37.565843          4    0.05  160.544  160.444  160.743
# 12 2024-06-28 11:11:37.575860          4    0.05  160.594  160.494  160.793
# 13 2024-06-28 11:11:37.583677          4    0.05  160.595  160.494  160.793
# 14 2024-06-28 11:11:37.587722          3    0.05  160.793  160.893  160.594
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# 11  10027
# 12  10027
# 13  10027
# 14  10027
# Invalid price for sell limit at 160.7935. Retrying with adjusted price.
# Failed to send order: OrderSendResult(retcode=10027, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='AutoTrading disabled by client', request_id=0, retcode_external=0, request=TradeRequest(action=5, magic=234000, order=0, symbol='USDJPYm', volume=0.05, price=162.401, stoplimit=0.0, sl=160.893, tp=160.594, deviation=10, type=3, type_filling=2, type_time=0, expiration=0, comment='Grid strategy', position=0, position_by=0))
# Logging trade: 3, 0.05, 162.401, 160.893, 160.594, 10027
# New trade DataFrame:
#                    timestamp  order_type  volume    price       sl       tp  \
# 0 2024-06-28 11:11:37.596243           3    0.05  162.401  160.893  160.594
#
#    result
# 0   10027
# Updated trade_log_df:
#                     timestamp order_type  volume    price       sl       tp  \
# 0  2024-06-28 11:11:37.403066          5    0.05  160.393  160.493  160.194
# 1  2024-06-28 11:11:37.443170          5    0.05  160.393  160.493  160.194
# 2  2024-06-28 11:11:37.456325          5    0.05  160.344  160.444  160.144
# 3  2024-06-28 11:11:37.465292          5    0.05  160.343  160.444  160.144
# 4  2024-06-28 11:11:37.476005          5    0.05  160.293  160.393  160.094
# 5  2024-06-28 11:11:37.488013          5    0.05  160.292  160.393  160.094
# 6  2024-06-28 11:11:37.509325          2    0.05  160.094  159.994  160.293
# 7  2024-06-28 11:11:37.515862          2    0.05  161.694  159.994  160.293
# 8  2024-06-28 11:11:37.533212          4    0.05  160.494  160.394  160.694
# 9  2024-06-28 11:11:37.545460          4    0.05  160.494  160.394  160.694
# 10 2024-06-28 11:11:37.556029          4    0.05  160.543  160.444  160.743
# 11 2024-06-28 11:11:37.565843          4    0.05  160.544  160.444  160.743
# 12 2024-06-28 11:11:37.575860          4    0.05  160.594  160.494  160.793
# 13 2024-06-28 11:11:37.583677          4    0.05  160.595  160.494  160.793
# 14 2024-06-28 11:11:37.587722          3    0.05  160.793  160.893  160.594
# 15 2024-06-28 11:11:37.596243          3    0.05  162.401  160.893  160.594
#
#    result
# 0   10027
# 1   10027
# 2   10027
# 3   10027
# 4   10027
# 5   10027
# 6   10027
# 7   10027
# 8   10027
# 9   10027
# 10  10027
# 11  10027
# 12  10027
# 13  10027
# 14  10027
# 15  10027
# Failed to place adjusted sell limit order at 162.401
# C:\Users\Owner\AppData\Local\Temp\ipykernel_17308\738732804.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   trade_log_df = pd.concat([trade_log_df, new_trade], ignore_index=True)
